sboxinxor_file = open("sbox_inxor.txt", "r")
sboxoutxor_file = open("sbox_outxor.txt", "r")
expandedb_file = open("expand_out_1.txt", "r")

keyfreq_file = open("keyfreq.txt", "a+")
    
# for each sbox component
for comp in range(8):
    print("SBOX {}".format(comp))
    # frequency of occurance of each key (in 6 bit chunks) using probabilistic prediction
    possible_key_freq = {0: 0}
    for i in range(64):
        possible_key_freq[i] = 0

    sboxinxor_file.seek(0)
    sboxoutxor_file.seek(0)
    expandedb_file.seek(0)

    for line in range(45000):
        
        inxor = sboxinxor_file.readline()
        outxor = sboxoutxor_file.readline()
        expanded = expandedb_file.readline()
        
        # input and output of ith sbox
        si_oxor = int(outxor[comp*4:comp*4+4], 2)
        si_ixor = int(inxor[comp*6:comp*6+6], 2)
        exp_bits = int(expanded[comp*6:comp*6+6], 2)
        
        # possible sbox input values satisfying the xor equations
        sboxin_bits = [] 
        
        for sout1 in range(16):
            sout2 = si_oxor ^ sout1
            possible_in1 = [i for i, e in enumerate(sbox[comp]) if e == sout1]
            possible_in2 = [i for i, e in enumerate(sbox[comp]) if e == sout2]
            for i in possible_in1:
                for j in possible_in2:
                    if i ^ j == si_ixor:
                        sboxin_bits.append(i)
        for i in range(len(sboxin_bits)):
            possible_key_freq[sboxin_bits[i] ^ exp_bits] += 1
            
    keyfreq_file.write("\nSBox-{}\n".format(comp))
    for i in range(64):
        keyfreq_file.write("{}:{} \t".format(i, possible_key_freq[i]))
    
    print("Key freq: {}".format(possible_key_freq))
    average = 0
    for k, v in possible_key_freq.items():
        average += possible_key_freq[k]
    average /= len(possible_key_freq)
        
    maxv1 = max(possible_key_freq.keys(), key = (lambda key: possible_key_freq[key]))
    possible_key_freq[maxv1] = 0
    maxv2 = max(possible_key_freq.keys(), key = (lambda key: possible_key_freq[key]))
    keyfreq_file.write("\nMax: {}\n".format(maxv1))
    for k, v in possible_key_freq.items():
        possible_key_freq[k] -= average
    keyfreq_file.write("Distance from mean = {}:\n{}\n".format(average, possible_key_freq))
    print("\nMax: {}, {}\n".format(maxv1, maxv2))
    print("Distance from mean (= {}):\n{}\n".format(average, possible_key_freq))
# Out:
# SBOX 0
# Key freq: {0: 2877, 1: 2968, 2: 2887, 3: 2840, 4: 2870, 5: 2910, 6: 2919, 7: 2909, 8: 2899, 9: 3036, 10: 3003, 11: 2963, 12: 2883, 13: 2906, 14: 2831, 15: 2775, 16: 2957, 17: 2801, 18: 2924, 19: 2929, 20: 3024, 21: 3759, 22: 2951, 23: 2925, 24: 2884, 25: 2849, 26: 2850, 27: 2840, 28: 2983, 29: 3036, 30: 2848, 31: 2841, 32: 2992, 33: 2983, 34: 2852, 35: 2907, 36: 2937, 37: 2815, 38: 2884, 39: 2882, 40: 2914, 41: 2969, 42: 2878, 43: 2890, 44: 2792, 45: 2941, 46: 2829, 47: 2885, 48: 2823, 49: 2974, 50: 2923, 51: 2869, 52: 2912, 53: 2939, 54: 2901, 55: 2842, 56: 2895, 57: 2872, 58: 2934, 59: 2859, 60: 2879, 61: 2956, 62: 2968, 63: 2971}
#
# Max: 21, 9
#
# Distance from mean (= 2917.875):
# ...
